# %%
import pandas as pd

index = [
    ['Engineering', 'Engineering', 'Science', 'Science'],
    ['CSE', 'ECE', 'Physics', 'Chemistry']
]

multi_index = pd.MultiIndex.from_arrays(
    index,
    names=['Department', 'Branch']
)

marks = pd.Series(
    [80, 78, 92, 88],
    index=multi_index
)

print("Original Series:")
print(marks)

print("\nData for Engineering:")
print(marks.loc['Engineering'])


print("\nData for Science:")
print(marks.loc['Science'])
# Out:
# Original Series:
# Department   Branch
# Engineering  CSE          80
#              ECE          78
# Science      Physics      92
#              Chemistry    88
# dtype: int64
#
# Data for Engineering:
# Branch
# CSE    80
# ECE    78
# dtype: int64
#
# Data for Science:
# Branch
# Physics      92
# Chemistry    88
# dtype: int64

# %%
import pandas as pd

index = pd.MultiIndex.from_tuples(
    [
        ('Engineering', 'CSE'),
        ('Engineering', 'ECE'),
        ('Science', 'Physics'),
        ('Science', 'Chemistry')
    ],
    names=['Department', 'Branch']
)

data = pd.DataFrame(
    {
        '2025': [80, 70, 82, 88],
        '2026': [90, 86, 95, 97]
    },
    index=index
)

print("Original Tabular Data:")
print(data)

unstacked_data = data.unstack()

print("\nData after Unstack():")
print(unstacked_data)

stacked_data = unstacked_data.stack()

print("\nData after Stack():")
print(stacked_data)
# Out:
# Original Tabular Data:
#                        2025  2026
# Department  Branch
# Engineering CSE          80    90
#             ECE          70    86
# Science     Physics      82    95
#             Chemistry    88    97
#
# Data after Unstack():
#              2025                          2026
# Branch        CSE Chemistry   ECE Physics   CSE Chemistry   ECE Physics
# Department
# Engineering  80.0       NaN  70.0     NaN  90.0       NaN  86.0     NaN
# Science       NaN      88.0   NaN    82.0   NaN      97.0   NaN    95.0
#
# Data after Stack():
#                        2025  2026
# Department  Branch
# Engineering CSE        80.0  90.0
#             ECE        70.0  86.0
# Science     Chemistry  88.0  97.0
#             Physics    82.0  95.0
# C:\Users\geeth\AppData\Local\Temp\ipykernel_22296\2603219348.py:29: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   stacked_data = unstacked_data.stack()

# %%
import pandas as pd

df1 = pd.DataFrame(
    {
        'Name': ['Sd', 'Abhi', 'Sai'],
        'Marks': [70, None, 78],
        'Grade': ['A', 'B', None]
    },
    index=[101, 102, 103]
)

df2 = pd.DataFrame(
    {
        'Name': ['Sd', 'Abhi', 'Sai'],
        'Marks': [90, 88, 82],
        'Grade': [None, 'A', 'B']
    },
    index=[101, 102, 104]
)

print("First DataFrame:")
print(df1)

print("\nSecond DataFrame:")
print(df2)

merged = pd.merge(
    df1,
    df2,
    left_index=True,
    right_index=True,
    how='outer',
    suffixes=('_DF1', '_DF2')
)

print("\nMerged DataFrame:")
print(merged)

combined = df1.combine_first(df2)

print("\nDataFrame after combine_first():")
print(combined)
# Out:
# First DataFrame:
#      Name  Marks Grade
# 101    Sd   70.0     A
# 102  Abhi    NaN     B
# 103   Sai   78.0  None
#
# Second DataFrame:
#      Name  Marks Grade
# 101    Sd     90  None
# 102  Abhi     88     A
# 104   Sai     82     B
#
# Merged DataFrame:
#     Name_DF1  Marks_DF1 Grade_DF1 Name_DF2  Marks_DF2 Grade_DF2
# 101       Sd       70.0         A       Sd       90.0      None
# 102     Abhi        NaN         B     Abhi       88.0         A
# 103      Sai       78.0      None      NaN        NaN       NaN
# 104      NaN        NaN       NaN      Sai       82.0         B
#
# DataFrame after combine_first():
#      Name  Marks Grade
# 101    Sd   70.0     A
# 102  Abhi   88.0     B
# 103   Sai   78.0   NaN
# 104   Sai   82.0     B
